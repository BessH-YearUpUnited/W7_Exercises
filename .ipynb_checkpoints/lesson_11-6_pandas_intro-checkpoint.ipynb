# %% [markdown]
# # pandas Basics

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a Series
#
# A series contains one dimension, like a column.

# %%
a_list = [3, 217, 182]
a_list
# Out:
# [3, 217, 182]

# %%
a_index = ['a','b','c']

# %%
a = pd.Series(a_list, index=a_index)
a
# Out:
# a      3
# b    217
# c    182
# dtype: int64

# %%
a_no_index = pd.Series(a_list)
a_no_index
# Out:
# 0      3
# 1    217
# 2    182
# dtype: int64

# %%
b_dict = {'cat': 'Norma', 'dog': 'Fozzie', 'fish': 'Al'}
b_dict
# Out:
# {'cat': 'Norma', 'dog': 'Fozzie', 'fish': 'Al'}

# %%
b = pd.Series(b_dict)
b
# Out:
# cat      Norma
# dog     Fozzie
# fish        Al
# dtype: object

# %% [markdown]
# ### Creating a DataFrame
# A DataFrame contains two dimensions (rows and columns) and displays as a table.

# %%
data = {
    "product_num": [1658, 2476, 3911],
    "quantity": [120, 54, 98]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    product_num  quantity
# 0         1658       120
# 1         2476        54
# 2         3911        98

# %%
df
# Out:
#    product_num  quantity
# 0         1658       120
# 1         2476        54
# 2         3911        98

# %%
# You can also export a DataFrame to a string

df.to_string()
# Out:
# '   product_num  quantity\n0         1658       120\n1         2476        54\n2         3911        98'

# %%
df01 = pd.DataFrame((1,2,3,4)) 
df01
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
arr = np.array([1,2,3,4]) 
df02 = pd.DataFrame(arr) 
df02
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
ser = pd.Series(arr) 
df03 = pd. DataFrame(ser)
df03
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
arr2 = np.array([[1,2,3,4]]) 
df04 = pd.DataFrame(arr2)
df04
# Out:
#    0  1  2  3
# 0  1  2  3  4

# %%
df04.insert(2, 'A', ['a'])
df04.insert(5, 'D', ['d'])
df04
# Out:
#    0  1  A  2  3  D
# 0  1  2  a  3  4  d

# %%
# NumPy Sampling -- using .arange() and .reshape() to populate a DataFrame

sampledata = pd.DataFrame(np.arange(8).reshape((2,4)), index=['apple','banana'], columns=['a','b','c','d'])
sampledata
# Out:
#         a  b  c  d
# apple   0  1  2  3
# banana  4  5  6  7

# %%
sampledata['banana':]
# Out:
#         a  b  c  d
# banana  4  5  6  7

# %% [markdown]
# ### Using .loc[] and .iloc[]
#
# The .loc[] attribute works with the named index of a DataFrame. The .iloc[] attribute uses the underlying numbered index.

# %%
data = { "product_num": [1658, 2476, 3911], "quantity": [120, 54, 98] } 
inventory = pd.DataFrame(data)
inventory
# Out:
#    product_num  quantity
# 0         1658       120
# 1         2476        54
# 2         3911        98

# %%
print(type(inventory.loc[1]))
inventory.loc[1]
# Out:
# <class 'pandas.core.series.Series'>
# product_num    2476
# quantity         54
# Name: 1, dtype: int64

# %%
print(type(inventory.loc[1:2]))
inventory.loc[1:2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    product_num  quantity
# 1         2476        54
# 2         3911        98

# %%
sampledata
# Out:
#         a  b  c  d
# apple   0  1  2  3
# banana  4  5  6  7

# %%
sampledata.loc['orange'] = [11, 12, 13, 14]
sampledata
# Out:
#          a   b   c   d
# apple    0   1   2   3
# banana   4   5   6   7
# orange  11  12  13  14

# %%
sampledata.iloc[2] = [21, 31, 41, 51]
sampledata
# Out:
#          a   b   c   d
# apple    0   1   2   3
# banana   4   5   6   7
# orange  21  31  41  51

# %%
sampledata.loc['banana':'orange']
# Out:
#          a   b   c   d
# banana   4   5   6   7
# orange  21  31  41  51

# %%
sampledata.iloc[1:]
# Out:
#          a   b   c   d
# banana   4   5   6   7
# orange  21  31  41  51

# %% [markdown]
# ### Reading Files into a DataFrame

# %%
# available file formats for import include .txt, .csv, .json, .xlsx

df_country = pd.read_json('country_data.json')

df_country.tail(10)
# Out:
#          Name Continent          Region  SurfaceArea  IndepYear  Population  \
# 974    Zambia    Africa  Eastern Africa     752618.0     1964.0     9169000
# 975    Zambia    Africa  Eastern Africa     752618.0     1964.0     9169000
# 976    Zambia    Africa  Eastern Africa     752618.0     1964.0     9169000
# 977    Zambia    Africa  Eastern Africa     752618.0     1964.0     9169000
# 978    Zambia    Africa  Eastern Africa     752618.0     1964.0     9169000
# 979    Zambia    Africa  Eastern Africa     752618.0     1964.0     9169000
# 980  Zimbabwe    Africa  Eastern Africa     390757.0     1980.0    11669000
# 981  Zimbabwe    Africa  Eastern Africa     390757.0     1980.0    11669000
# 982  Zimbabwe    Africa  Eastern Africa     390757.0     1980.0    11669000
# 983  Zimbabwe    Africa  Eastern Africa     390757.0     1980.0    11669000
#
#      LifeExpectancy     GNP LocalName Language
# 974            37.2  3377.0    Zambia    Bemba
# 975            37.2  3377.0    Zambia    Chewa
# 976            37.2  3377.0    Zambia     Lozi
# 977            37.2  3377.0    Zambia   Nsenga
# 978            37.2  3377.0    Zambia   Nyanja
# 979            37.2  3377.0    Zambia   Tongan
# 980            37.8  5951.0  Zimbabwe  English
# 981            37.8  5951.0  Zimbabwe  Ndebele
# 982            37.8  5951.0  Zimbabwe   Nyanja
# 983            37.8  5951.0  Zimbabwe    Shona

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            984 non-null    object
#  1   Continent       984 non-null    object
#  2   Region          984 non-null    object
#  3   SurfaceArea     984 non-null    float64
#  4   IndepYear       892 non-null    float64
#  5   Population      984 non-null    int64
#  6   LifeExpectancy  967 non-null    float64
#  7   GNP             984 non-null    float64
#  8   LocalName       984 non-null    object
#  9   Language        984 non-null    object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 77.0+ KB

# %%
df_country.describe()
# Out:
#         SurfaceArea    IndepYear    Population  LifeExpectancy           GNP
# count  9.840000e+02   892.000000  9.840000e+02      967.000000  9.840000e+02
# mean   1.104603e+06  1809.380045  5.435588e+07       64.336298  2.339295e+05
# std    2.690225e+06   546.268082  1.801283e+08       12.241236  1.002474e+06
# min    4.000000e-01 -1523.000000  0.000000e+00       37.200000  0.000000e+00
# 25%    3.051800e+04  1905.000000  2.024000e+06       54.150000  1.706000e+03
# 50%    2.375955e+05  1958.000000  8.678200e+06       68.000000  8.005000e+03
# 75%    8.015900e+05  1971.000000  3.114700e+07       74.500000  7.369200e+04
# max    1.707540e+07  1994.000000  1.277558e+09       83.500000  8.510700e+06

# %%
df_export = (df_country[0:100])
df_export.tail(5)
# Out:
#                       Name      Continent           Region  SurfaceArea  \
# 95                 Bahrain           Asia      Middle East        694.0
# 96                 Bahamas  North America        Caribbean      13878.0
# 97                 Bahamas  North America        Caribbean      13878.0
# 98  Bosnia and Herzegovina         Europe  Southern Europe      51197.0
# 99                 Belarus         Europe   Eastern Europe     207600.0
#
#     IndepYear  Population  LifeExpectancy      GNP            LocalName  \
# 95     1971.0      617000            73.0   6366.0           Al-Bahrayn
# 96     1973.0      307000            71.1   3527.0          The Bahamas
# 97     1973.0      307000            71.1   3527.0          The Bahamas
# 98     1992.0     3972000            71.5   2841.0  Bosna i Hercegovina
# 99     1991.0    10236000            68.0  13714.0              Belarus
#
#           Language
# 95         English
# 96  Creole English
# 97   Creole French
# 98  Serbo-Croatian
# 99     Belorussian

# %%
df_export.to_csv('country_data_export.csv', index=False)

# %% [markdown]
# ### Side note: Max Rows
# Settings in pandas default to displaying a maximum of 60 rows for a DataFrame. You can check your current settings with the statement below:

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# If you want to chance your max rows setting, you can use the same statement and assign a new row value:

# %% [raw]
# pd.options.display.max_rows = 500   # or whatever max number you choose to set

# %% [markdown]
# #
# # Cleaning Data with Pandas

# %%
df_s = pd.read_csv('survey_data.csv')
df_s
# Out:
#       ID        Timestamp  Age                   Country Postal Code  Min Sib  \
# 0      1  6/21/2024 12:50   42             United States       60189        1
# 1      2  6/21/2024 13:23   33                       USA       59086        5
# 2      3  6/21/2024 13:35   52                       USA       97219        0
# 3      4  6/21/2024 13:40   65  United States of America       55118        5
# 4      5  6/21/2024 13:50   51            United States        55116        1
# ..   ...              ...  ...                       ...         ...      ...
# 120  121  9/23/2024 11:36   21             United States       60104        3
# 121  122  9/23/2024 11:36   19             United States       60616        5
# 122  123  9/23/2024 11:36   30            United States        60805        5
# 123  124  9/23/2024 11:36   25  United States of America       60473        3
# 124  125  9/23/2024 11:37   19             United States       60443        1
#
#      Max Sib                   TV_Amount                             Muppet  \
# 0        2.0          3-6 hours per week                      Rizzo the Rat
# 1        NaN          6-8 hours per week                    Gonzo the Great
# 2        0.0          1-3 hours per week  Beaker.  A thousand times Beaker.
# 3        NaN  More than 8 hours per week                        Fozzie Bear
# 4        2.0  More than 8 hours per week                             Animal
# ..       ...                         ...                                ...
# 120      4.0          3-6 hours per week                         Miss Piggy
# 121      NaN          6-8 hours per week                             Beaker
# 122      NaN          6-8 hours per week                    Kermit the Frog
# 123      4.0  More than 8 hours per week                      Cooke Monster
# 124      2.0          6-8 hours per week                             Animal
#
#     Ghost_Belief Ghost_Encounter Rock_Paper_Scissors
# 0          Maybe           Maybe               Paper
# 1          Maybe              No            Scissors
# 2          Maybe           Maybe                Rock
# 3            Yes             Yes               Paper
# 4            Yes           Maybe                Rock
# ..           ...             ...                 ...
# 120          Yes             Yes            Scissors
# 121          Yes           Maybe                Rock
# 122          Yes              No            Scissors
# 123        Maybe              No            Scissors
# 124           No              No            Scissors
#
# [125 rows x 12 columns]

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   125 non-null    int64
#  1   Timestamp            125 non-null    object
#  2   Age                  125 non-null    int64
#  3   Country              125 non-null    object
#  4   Postal Code          124 non-null    object
#  5   Min Sib              125 non-null    int64
#  6   Max Sib              117 non-null    float64
#  7   TV_Amount            125 non-null    object
#  8   Muppet               125 non-null    object
#  9   Ghost_Belief         124 non-null    object
#  10  Ghost_Encounter      125 non-null    object
#  11  Rock_Paper_Scissors  125 non-null    object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 11.8+ KB

# %%
df_s2 = df_s.dropna()
df_s2
# Out:
#       ID        Timestamp  Age                   Country Postal Code  Min Sib  \
# 0      1  6/21/2024 12:50   42             United States       60189        1
# 2      3  6/21/2024 13:35   52                       USA       97219        0
# 4      5  6/21/2024 13:50   51            United States        55116        1
# 5      6  6/21/2024 14:01   28                       USA       43207        1
# 6      7  6/21/2024 14:02   40                       Usa       53704        1
# ..   ...              ...  ...                       ...         ...      ...
# 118  119  9/23/2024 11:36   28             United States       60626        3
# 119  120  9/23/2024 11:36   29             United States       60632        1
# 120  121  9/23/2024 11:36   21             United States       60104        3
# 123  124  9/23/2024 11:36   25  United States of America       60473        3
# 124  125  9/23/2024 11:37   19             United States       60443        1
#
#      Max Sib                   TV_Amount                             Muppet  \
# 0        2.0          3-6 hours per week                      Rizzo the Rat
# 2        0.0          1-3 hours per week  Beaker.  A thousand times Beaker.
# 4        2.0  More than 8 hours per week                             Animal
# 5        2.0          3-6 hours per week                      Rizzo the Rat
# 6        2.0   Less than 1 hour per week    I do not have a favorite Muppet
# ..       ...                         ...                                ...
# 118      4.0          6-8 hours per week                    Kermit the Frog
# 119      2.0  More than 8 hours per week    I do not have a favorite Muppet
# 120      4.0          3-6 hours per week                         Miss Piggy
# 123      4.0  More than 8 hours per week                      Cooke Monster
# 124      2.0          6-8 hours per week                             Animal
#
#     Ghost_Belief Ghost_Encounter Rock_Paper_Scissors
# 0          Maybe           Maybe               Paper
# 2          Maybe           Maybe                Rock
# 4            Yes           Maybe                Rock
# 5          Maybe           Maybe                Rock
# 6             No              No                Rock
# ..           ...             ...                 ...
# 118          Yes           Maybe               Paper
# 119          Yes           Maybe               Paper
# 120          Yes             Yes            Scissors
# 123        Maybe              No            Scissors
# 124           No              No            Scissors
#
# [115 rows x 12 columns]

# %%
df_s2.drop([119,120], axis=0, inplace=True)
df_s2
# Out:
# C:\Users\elizh\AppData\Local\Temp\ipykernel_26200\2131160590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2.drop([119,120], axis=0, inplace=True)
#       ID        Timestamp  Age                   Country Postal Code  Min Sib  \
# 0      1  6/21/2024 12:50   42             United States       60189        1
# 2      3  6/21/2024 13:35   52                       USA       97219        0
# 4      5  6/21/2024 13:50   51            United States        55116        1
# 5      6  6/21/2024 14:01   28                       USA       43207        1
# 6      7  6/21/2024 14:02   40                       Usa       53704        1
# ..   ...              ...  ...                       ...         ...      ...
# 116  117  9/23/2024 11:35   24             United States       60647        3
# 117  118  9/23/2024 11:35   25             United States       60532        3
# 118  119  9/23/2024 11:36   28             United States       60626        3
# 123  124  9/23/2024 11:36   25  United States of America       60473        3
# 124  125  9/23/2024 11:37   19             United States       60443        1
#
#      Max Sib                   TV_Amount                             Muppet  \
# 0        2.0          3-6 hours per week                      Rizzo the Rat
# 2        0.0          1-3 hours per week  Beaker.  A thousand times Beaker.
# 4        2.0  More than 8 hours per week                             Animal
# 5        2.0          3-6 hours per week                      Rizzo the Rat
# 6        2.0   Less than 1 hour per week    I do not have a favorite Muppet
# ..       ...                         ...                                ...
# 116      4.0  More than 8 hours per week                    Kermit the Frog
# 117      4.0          6-8 hours per week                    Gonzo the Great
# 118      4.0          6-8 hours per week                    Kermit the Frog
# 123      4.0  More than 8 hours per week                      Cooke Monster
# 124      2.0          6-8 hours per week                             Animal
#
#     Ghost_Belief Ghost_Encounter Rock_Paper_Scissors
# 0          Maybe           Maybe               Paper
# 2          Maybe           Maybe                Rock
# 4            Yes           Maybe                Rock
# 5          Maybe           Maybe                Rock
# 6             No              No                Rock
# ..           ...             ...                 ...
# 116          Yes           Maybe            Scissors
# 117          Yes           Maybe               Paper
# 118          Yes           Maybe               Paper
# 123        Maybe              No            Scissors
# 124           No              No            Scissors
#
# [113 rows x 12 columns]

# %%
df_s2 = df_s2.drop_duplicates()
df_s2
# Out:
#       ID        Timestamp  Age                   Country Postal Code  Min Sib  \
# 0      1  6/21/2024 12:50   42             United States       60189        1
# 2      3  6/21/2024 13:35   52                       USA       97219        0
# 4      5  6/21/2024 13:50   51            United States        55116        1
# 5      6  6/21/2024 14:01   28                       USA       43207        1
# 6      7  6/21/2024 14:02   40                       Usa       53704        1
# ..   ...              ...  ...                       ...         ...      ...
# 116  117  9/23/2024 11:35   24             United States       60647        3
# 117  118  9/23/2024 11:35   25             United States       60532        3
# 118  119  9/23/2024 11:36   28             United States       60626        3
# 123  124  9/23/2024 11:36   25  United States of America       60473        3
# 124  125  9/23/2024 11:37   19             United States       60443        1
#
#      Max Sib                   TV_Amount                             Muppet  \
# 0        2.0          3-6 hours per week                      Rizzo the Rat
# 2        0.0          1-3 hours per week  Beaker.  A thousand times Beaker.
# 4        2.0  More than 8 hours per week                             Animal
# 5        2.0          3-6 hours per week                      Rizzo the Rat
# 6        2.0   Less than 1 hour per week    I do not have a favorite Muppet
# ..       ...                         ...                                ...
# 116      4.0  More than 8 hours per week                    Kermit the Frog
# 117      4.0          6-8 hours per week                    Gonzo the Great
# 118      4.0          6-8 hours per week                    Kermit the Frog
# 123      4.0  More than 8 hours per week                      Cooke Monster
# 124      2.0          6-8 hours per week                             Animal
#
#     Ghost_Belief Ghost_Encounter Rock_Paper_Scissors
# 0          Maybe           Maybe               Paper
# 2          Maybe           Maybe                Rock
# 4            Yes           Maybe                Rock
# 5          Maybe           Maybe                Rock
# 6             No              No                Rock
# ..           ...             ...                 ...
# 116          Yes           Maybe            Scissors
# 117          Yes           Maybe               Paper
# 118          Yes           Maybe               Paper
# 123        Maybe              No            Scissors
# 124           No              No            Scissors
#
# [113 rows x 12 columns]

# %%
df_s2.duplicated()
# Out:
# 0      False
# 2      False
# 4      False
# 5      False
# 6      False
#        ...
# 116    False
# 117    False
# 118    False
# 123    False
# 124    False
# Length: 113, dtype: bool

# %%
filtered_df = df_s2[(df_s2['Ghost_Belief'] == 'Yes')]
filtered_df
# Out:
#       ID        Timestamp  Age                    Country      Postal Code  \
# 4      5  6/21/2024 13:50   51             United States             55116
# 10    11  6/21/2024 14:52   52              United States            55104
# 14    15  6/21/2024 20:06   42                   America   Somewhere in WI
# 15    16  6/21/2024 20:32   18              United States            54016
# 16    17  6/21/2024 20:35   44  United States of America             54016
# 17    18  6/21/2024 20:43    8             United States             55102
# 20    21  6/21/2024 21:03   55                       USA             10024
# 22    23  6/21/2024 23:25   42              United States            55104
# 23    24   6/22/2024 4:40   70  United States of America             55119
# 25    26   6/22/2024 7:08   46   United States of America            55434
# 28    29  6/22/2024 12:18   42                        Usa            55439
# 34    35   6/23/2024 7:42   41             United States             49546
# 39    40  6/24/2024 12:39   65                        USA            55416
# 41    42  6/24/2024 13:46   63              United Stayes            55071
# 42    43  6/24/2024 14:08   32                        USA            60202
# 58    59  6/25/2024 15:26   33                        USA            37211
# 61    62   6/26/2024 1:04   56                        USA            99504
# 63    64   6/26/2024 7:03   57              United States            55038
# 68    69  6/28/2024 23:26   51              United States            30338
# 72    73   6/29/2024 6:53   30                      Italy            54027
# 73    74   6/29/2024 8:33   56                        usa            19033
# 76    77  6/29/2024 22:12   43              United States            55128
# 79    80  6/29/2024 22:52   41                         US            45215
# 82    83  6/30/2024 18:07   38              United States            94530
# 83    84  6/30/2024 20:00   47                        USA            90301
# 84    85  6/30/2024 22:50   37             United States             55406
# 85    86    7/1/2024 6:06   40              United States            33596
# 86    87    7/1/2024 7:27   27  United States of America             75455
# 87    88    7/1/2024 7:28   46             United States             43016
# 89    90   7/1/2024 12:03   44             United States             30228
# 91    92   7/1/2024 17:01   32             United States             30296
# 93    94   7/1/2024 17:21   36              United States            93662
# 97    98   7/1/2024 17:53   47                        usa            79022
# 103  104  7/11/2024 23:44   32                         US            78664
# 106  107  9/23/2024 11:34   26              North America            60608
# 107  108  9/23/2024 11:34   23              United States            60402
# 116  117  9/23/2024 11:35   24              United States            60647
# 117  118  9/23/2024 11:35   25              United States            60532
# 118  119  9/23/2024 11:36   28              United States            60626
#
#      Min Sib  Max Sib                   TV_Amount  \
# 4          1      2.0  More than 8 hours per week
# 10         1      2.0  More than 8 hours per week
# 14         1      2.0          3-6 hours per week
# 15         1      2.0          3-6 hours per week
# 16         1      2.0          3-6 hours per week
# 17         1      2.0          6-8 hours per week
# 20         0      0.0          3-6 hours per week
# 22         1      2.0          1-3 hours per week
# 23         1      2.0          1-3 hours per week
# 25         3      4.0  More than 8 hours per week
# 28         1      2.0          3-6 hours per week
# 34         1      2.0          6-8 hours per week
# 39         1      2.0  More than 8 hours per week
# 41         0      0.0          3-6 hours per week
# 42         0      0.0          3-6 hours per week
# 58         3      4.0          1-3 hours per week
# 61         1      2.0          1-3 hours per week
# 63         1      2.0          6-8 hours per week
# 68         1      2.0          6-8 hours per week
# 72         0      0.0  More than 8 hours per week
# 73         1      2.0          3-6 hours per week
# 76         1      2.0          6-8 hours per week
# 79         0      0.0          6-8 hours per week
# 82         1      2.0          3-6 hours per week
# 83         3      4.0  More than 8 hours per week
# 84         1      2.0          1-3 hours per week
# 85         1      2.0          3-6 hours per week
# 86         1      2.0  More than 8 hours per week
# 87         1      2.0          1-3 hours per week
# 89         1      2.0  More than 8 hours per week
# 91         1      2.0          3-6 hours per week
# 93         1      2.0  More than 8 hours per week
# 97         1      2.0          6-8 hours per week
# 103        0      0.0  More than 8 hours per week
# 106        1      2.0  More than 8 hours per week
# 107        1      2.0  More than 8 hours per week
# 116        3      4.0  More than 8 hours per week
# 117        3      4.0          6-8 hours per week
# 118        3      4.0          6-8 hours per week
#
#                               Muppet Ghost_Belief Ghost_Encounter  \
# 4                             Animal          Yes           Maybe
# 10                            Animal          Yes           Maybe
# 14                        Miss Piggy          Yes             Yes
# 15                   Kermit the Frog          Yes             Yes
# 16                            Animal          Yes           Maybe
# 17                   Kermit the Frog          Yes             Yes
# 20                   Gonzo the Great          Yes             Yes
# 22                   Kermit the Frog          Yes             Yes
# 23                        Miss Piggy          Yes              No
# 25                       Fozzie Bear          Yes             Yes
# 28                   Kermit the Frog          Yes           Maybe
# 34                   Kermit the Frog          Yes           Maybe
# 39   I do not have a favorite Muppet          Yes              No
# 41                       Fozzie Bear          Yes              No
# 42                        Miss Piggy          Yes             Yes
# 58                            Animal          Yes           Maybe
# 61                        Miss Piggy          Yes              No
# 63                   Kermit the Frog          Yes             Yes
# 68   I do not have a favorite Muppet          Yes             Yes
# 72                        Miss Piggy          Yes           Maybe
# 73                   Kermit the Frog          Yes           Maybe
# 76                   Gonzo the Great          Yes           Maybe
# 79                        Miss Piggy          Yes             Yes
# 82   I do not have a favorite Muppet          Yes           Maybe
# 83   I do not have a favorite Muppet          Yes             Yes
# 84                            Animal          Yes             Yes
# 85                            Animal          Yes             Yes
# 86                        Miss Piggy          Yes             Yes
# 87   I do not have a favorite Muppet          Yes              No
# 89                        Miss Piggy          Yes             Yes
# 91   I do not have a favorite Muppet          Yes           Maybe
# 93                            Animal          Yes           Maybe
# 97                   Gonzo the Great          Yes             Yes
# 103                           Animal          Yes             Yes
# 106  I do not have a favorite Muppet          Yes             Yes
# 107                             Pepe          Yes             Yes
# 116                  Kermit the Frog          Yes           Maybe
# 117                  Gonzo the Great          Yes           Maybe
# 118                  Kermit the Frog          Yes           Maybe
#
#     Rock_Paper_Scissors
# 4                  Rock
# 10                Paper
# 14             Scissors
# 15                Paper
# 16                 Rock
# 17                 Rock
# 20                Paper
# 22                Paper
# 23             Scissors
# 25                 Rock
# 28                 Rock
# 34                 Rock
# 39                 Rock
# 41                Paper
# 42             Scissors
# 58             Scissors
# 61             Scissors
# 63                 Rock
# 68             Scissors
# 72             Scissors
# 73             Scissors
# 76                 Rock
# 79                 Rock
# 82             Scissors
# 83             Scissors
# 84                 Rock
# 85                Paper
# 86                 Rock
# 87             Scissors
# 89                 Rock
# 91                Paper
# 93                Paper
# 97                Paper
# 103            Scissors
# 106                Rock
# 107               Paper
# 116            Scissors
# 117               Paper
# 118               Paper

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 4 to 118
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   39 non-null     int64
#  1   Timestamp            39 non-null     object
#  2   Age                  39 non-null     int64
#  3   Country              39 non-null     object
#  4   Postal Code          39 non-null     object
#  5   Min Sib              39 non-null     int64
#  6   Max Sib              39 non-null     float64
#  7   TV_Amount            39 non-null     object
#  8   Muppet               39 non-null     object
#  9   Ghost_Belief         39 non-null     object
#  10  Ghost_Encounter      39 non-null     object
#  11  Rock_Paper_Scissors  39 non-null     object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 4.0+ KB

# %%
df_s2.replace({'Country':'United States of America'}, 'United States', inplace=True)
df_s2
# Out:
#       ID        Timestamp  Age         Country Postal Code  Min Sib  Max Sib  \
# 0      1  6/21/2024 12:50   42   United States       60189        1      2.0
# 2      3  6/21/2024 13:35   52             USA       97219        0      0.0
# 4      5  6/21/2024 13:50   51  United States        55116        1      2.0
# 5      6  6/21/2024 14:01   28             USA       43207        1      2.0
# 6      7  6/21/2024 14:02   40             Usa       53704        1      2.0
# ..   ...              ...  ...             ...         ...      ...      ...
# 116  117  9/23/2024 11:35   24   United States       60647        3      4.0
# 117  118  9/23/2024 11:35   25   United States       60532        3      4.0
# 118  119  9/23/2024 11:36   28   United States       60626        3      4.0
# 123  124  9/23/2024 11:36   25   United States       60473        3      4.0
# 124  125  9/23/2024 11:37   19   United States       60443        1      2.0
#
#                       TV_Amount                             Muppet  \
# 0            3-6 hours per week                      Rizzo the Rat
# 2            1-3 hours per week  Beaker.  A thousand times Beaker.
# 4    More than 8 hours per week                             Animal
# 5            3-6 hours per week                      Rizzo the Rat
# 6     Less than 1 hour per week    I do not have a favorite Muppet
# ..                          ...                                ...
# 116  More than 8 hours per week                    Kermit the Frog
# 117          6-8 hours per week                    Gonzo the Great
# 118          6-8 hours per week                    Kermit the Frog
# 123  More than 8 hours per week                      Cooke Monster
# 124          6-8 hours per week                             Animal
#
#     Ghost_Belief Ghost_Encounter Rock_Paper_Scissors
# 0          Maybe           Maybe               Paper
# 2          Maybe           Maybe                Rock
# 4            Yes           Maybe                Rock
# 5          Maybe           Maybe                Rock
# 6             No              No                Rock
# ..           ...             ...                 ...
# 116          Yes           Maybe            Scissors
# 117          Yes           Maybe               Paper
# 118          Yes           Maybe               Paper
# 123        Maybe              No            Scissors
# 124           No              No            Scissors
#
# [113 rows x 12 columns]

# %%
df_s2.replace({'Country':'USA'}, 'United States', inplace=True)
df_s2
# Out:
#       ID        Timestamp  Age         Country Postal Code  Min Sib  Max Sib  \
# 0      1  6/21/2024 12:50   42   United States       60189        1      2.0
# 2      3  6/21/2024 13:35   52   United States       97219        0      0.0
# 4      5  6/21/2024 13:50   51  United States        55116        1      2.0
# 5      6  6/21/2024 14:01   28   United States       43207        1      2.0
# 6      7  6/21/2024 14:02   40             Usa       53704        1      2.0
# ..   ...              ...  ...             ...         ...      ...      ...
# 116  117  9/23/2024 11:35   24   United States       60647        3      4.0
# 117  118  9/23/2024 11:35   25   United States       60532        3      4.0
# 118  119  9/23/2024 11:36   28   United States       60626        3      4.0
# 123  124  9/23/2024 11:36   25   United States       60473        3      4.0
# 124  125  9/23/2024 11:37   19   United States       60443        1      2.0
#
#                       TV_Amount                             Muppet  \
# 0            3-6 hours per week                      Rizzo the Rat
# 2            1-3 hours per week  Beaker.  A thousand times Beaker.
# 4    More than 8 hours per week                             Animal
# 5            3-6 hours per week                      Rizzo the Rat
# 6     Less than 1 hour per week    I do not have a favorite Muppet
# ..                          ...                                ...
# 116  More than 8 hours per week                    Kermit the Frog
# 117          6-8 hours per week                    Gonzo the Great
# 118          6-8 hours per week                    Kermit the Frog
# 123  More than 8 hours per week                      Cooke Monster
# 124          6-8 hours per week                             Animal
#
#     Ghost_Belief Ghost_Encounter Rock_Paper_Scissors
# 0          Maybe           Maybe               Paper
# 2          Maybe           Maybe                Rock
# 4            Yes           Maybe                Rock
# 5          Maybe           Maybe                Rock
# 6             No              No                Rock
# ..           ...             ...                 ...
# 116          Yes           Maybe            Scissors
# 117          Yes           Maybe               Paper
# 118          Yes           Maybe               Paper
# 123        Maybe              No            Scissors
# 124           No              No            Scissors
#
# [113 rows x 12 columns]

# %%
df_s.head(5)
# Out:
#    ID        Timestamp  Age                   Country Postal Code  Min Sib  \
# 0   1  6/21/2024 12:50   42             United States       60189        1
# 1   2  6/21/2024 13:23   33                       USA       59086        5
# 2   3  6/21/2024 13:35   52                       USA       97219        0
# 3   4  6/21/2024 13:40   65  United States of America       55118        5
# 4   5  6/21/2024 13:50   51            United States        55116        1
#
#    Max Sib                   TV_Amount                             Muppet  \
# 0      2.0          3-6 hours per week                      Rizzo the Rat
# 1      NaN          6-8 hours per week                    Gonzo the Great
# 2      0.0          1-3 hours per week  Beaker.  A thousand times Beaker.
# 3      NaN  More than 8 hours per week                        Fozzie Bear
# 4      2.0  More than 8 hours per week                             Animal
#
#   Ghost_Belief Ghost_Encounter Rock_Paper_Scissors
# 0        Maybe           Maybe               Paper
# 1        Maybe              No            Scissors
# 2        Maybe           Maybe                Rock
# 3          Yes             Yes               Paper
# 4          Yes           Maybe                Rock

# %%
# This was that pesky .fillna() example. I went back and changed the column reference 
# in the part after the equal sign to use bracket notation as you see below, and now it works. ¯\_(ツ)_/¯


df_s['Max Sib'] = df_s['Max Sib'].fillna('test')

# %%
for i in df_s2.index:
    if 'Beaker' in df_s2.loc[i, "Muppet"]:
        df_s2.loc[i, "Muppet"] = "Beaker"

df_s2
# Out:
#       ID        Timestamp  Age         Country Postal Code  Min Sib  Max Sib  \
# 0      1  6/21/2024 12:50   42   United States       60189        1      2.0
# 2      3  6/21/2024 13:35   52   United States       97219        0      0.0
# 4      5  6/21/2024 13:50   51  United States        55116        1      2.0
# 5      6  6/21/2024 14:01   28   United States       43207        1      2.0
# 6      7  6/21/2024 14:02   40             Usa       53704        1      2.0
# ..   ...              ...  ...             ...         ...      ...      ...
# 116  117  9/23/2024 11:35   24   United States       60647        3      4.0
# 117  118  9/23/2024 11:35   25   United States       60532        3      4.0
# 118  119  9/23/2024 11:36   28   United States       60626        3      4.0
# 123  124  9/23/2024 11:36   25   United States       60473        3      4.0
# 124  125  9/23/2024 11:37   19   United States       60443        1      2.0
#
#                       TV_Amount                           Muppet Ghost_Belief  \
# 0            3-6 hours per week                    Rizzo the Rat        Maybe
# 2            1-3 hours per week                           Beaker        Maybe
# 4    More than 8 hours per week                           Animal          Yes
# 5            3-6 hours per week                    Rizzo the Rat        Maybe
# 6     Less than 1 hour per week  I do not have a favorite Muppet           No
# ..                          ...                              ...          ...
# 116  More than 8 hours per week                  Kermit the Frog          Yes
# 117          6-8 hours per week                  Gonzo the Great          Yes
# 118          6-8 hours per week                  Kermit the Frog          Yes
# 123  More than 8 hours per week                    Cooke Monster        Maybe
# 124          6-8 hours per week                           Animal           No
#
#     Ghost_Encounter Rock_Paper_Scissors
# 0             Maybe               Paper
# 2             Maybe                Rock
# 4             Maybe                Rock
# 5             Maybe                Rock
# 6                No                Rock
# ..              ...                 ...
# 116           Maybe            Scissors
# 117           Maybe               Paper
# 118           Maybe               Paper
# 123              No            Scissors
# 124              No            Scissors
#
# [113 rows x 12 columns]

# %%
df_s2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113 entries, 0 to 124
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   113 non-null    int64
#  1   Timestamp            113 non-null    object
#  2   Age                  113 non-null    int64
#  3   Country              113 non-null    object
#  4   Postal Code          113 non-null    object
#  5   Min Sib              113 non-null    int64
#  6   Max Sib              113 non-null    float64
#  7   TV_Amount            113 non-null    object
#  8   Muppet               113 non-null    object
#  9   Ghost_Belief         113 non-null    object
#  10  Ghost_Encounter      113 non-null    object
#  11  Rock_Paper_Scissors  113 non-null    object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 15.5+ KB

# %%
for i in df_s2.index:
    if 'Wakanda' in df_s2.loc[i, "Country"]:
        df_s2.drop(i, inplace=True)

df_s2
# Out:
#       ID        Timestamp  Age         Country Postal Code  Min Sib  Max Sib  \
# 0      1  6/21/2024 12:50   42   United States       60189        1      2.0
# 2      3  6/21/2024 13:35   52   United States       97219        0      0.0
# 4      5  6/21/2024 13:50   51  United States        55116        1      2.0
# 5      6  6/21/2024 14:01   28   United States       43207        1      2.0
# 6      7  6/21/2024 14:02   40             Usa       53704        1      2.0
# ..   ...              ...  ...             ...         ...      ...      ...
# 116  117  9/23/2024 11:35   24   United States       60647        3      4.0
# 117  118  9/23/2024 11:35   25   United States       60532        3      4.0
# 118  119  9/23/2024 11:36   28   United States       60626        3      4.0
# 123  124  9/23/2024 11:36   25   United States       60473        3      4.0
# 124  125  9/23/2024 11:37   19   United States       60443        1      2.0
#
#                       TV_Amount                           Muppet Ghost_Belief  \
# 0            3-6 hours per week                    Rizzo the Rat        Maybe
# 2            1-3 hours per week                           Beaker        Maybe
# 4    More than 8 hours per week                           Animal          Yes
# 5            3-6 hours per week                    Rizzo the Rat        Maybe
# 6     Less than 1 hour per week  I do not have a favorite Muppet           No
# ..                          ...                              ...          ...
# 116  More than 8 hours per week                  Kermit the Frog          Yes
# 117          6-8 hours per week                  Gonzo the Great          Yes
# 118          6-8 hours per week                  Kermit the Frog          Yes
# 123  More than 8 hours per week                    Cooke Monster        Maybe
# 124          6-8 hours per week                           Animal           No
#
#     Ghost_Encounter Rock_Paper_Scissors
# 0             Maybe               Paper
# 2             Maybe                Rock
# 4             Maybe                Rock
# 5             Maybe                Rock
# 6                No                Rock
# ..              ...                 ...
# 116           Maybe            Scissors
# 117           Maybe               Paper
# 118           Maybe               Paper
# 123              No            Scissors
# 124              No            Scissors
#
# [113 rows x 12 columns]

# %%
print(df_s2['Muppet'])
# Out:
# 0                        Rizzo the Rat
# 2                               Beaker
# 4                               Animal
# 5                        Rizzo the Rat
# 6      I do not have a favorite Muppet
#                     ...
# 116                    Kermit the Frog
# 117                    Gonzo the Great
# 118                    Kermit the Frog
# 123                      Cooke Monster
# 124                             Animal
# Name: Muppet, Length: 113, dtype: object

# %%
print(df_s2.Muppet)
# Out:
# 0                        Rizzo the Rat
# 2                               Beaker
# 4                               Animal
# 5                        Rizzo the Rat
# 6      I do not have a favorite Muppet
#                     ...
# 116                    Kermit the Frog
# 117                    Gonzo the Great
# 118                    Kermit the Frog
# 123                      Cooke Monster
# 124                             Animal
# Name: Muppet, Length: 113, dtype: object
